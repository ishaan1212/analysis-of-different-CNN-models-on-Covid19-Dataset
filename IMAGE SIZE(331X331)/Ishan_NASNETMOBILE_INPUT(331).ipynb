# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D, AveragePooling2D
from keras.layers.merge import concatenate

from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Flatten, Dense
from keras.layers import Activation
from keras.layers import BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping

from tensorflow import keras

from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import SGD
import cv2, numpy as np

# %%
train_datagen_with_aug = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,
                                   shear_range=0.2,
                                   zoom_range=[0.2,0.5],
                                   width_shift_range = 0.3,
                                   height_shift_range = 0.3,
                                   validation_split=0.2)

train_generator = train_datagen_with_aug.flow_from_directory(
    r'D:\BARANIDHARAN SIR PROJECT\X-Ray Images Dataset for research project-20211204T084221Z-001',
    target_size=(331, 331),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='training'
    ) # set as training data

validation_generator = train_datagen_with_aug.flow_from_directory(
    r'D:\BARANIDHARAN SIR PROJECT\X-Ray Images Dataset for research project-20211204T084221Z-001', # same directory as training data
    target_size=(331, 331),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='validation'
    ) # set as validation data

input_img = Input(shape=(331, 331, 3))
# Out:
# Found 5171 images belonging to 3 classes.
# Found 1292 images belonging to 3 classes.

# %%
from keras.applications import nasnet

NASNET_MOBILE = Sequential()

nasnetmobile_model =keras.applications.nasnet.NASNetMobile(
    input_tensor=Input(shape=(331,331,3)), include_top=False, weights='imagenet',
    pooling=('max'), classes=3
)

# %%
for layer in nasnetmobile_model.layers:
    layer.trainable = False
    
NASNET_MOBILE.add(nasnetmobile_model)
NASNET_MOBILE.add(Flatten())
NASNET_MOBILE.add(Dense(512,activation='relu'))
NASNET_MOBILE.add(Dense(3, activation='softmax'))

NASNET_MOBILE.summary()

Adam = keras.optimizers.Adam(learning_rate=0.001)
NASNET_MOBILE.compile(optimizer=Adam, loss='categorical_crossentropy', metrics=['accuracy'])

graph = NASNET_MOBILE.fit(train_generator, epochs=25, validation_data = validation_generator)

graph
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# NASNet (Functional)          (None, 1056)              4269716
# _________________________________________________________________
# flatten (Flatten)            (None, 1056)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               541184
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 4,812,439
# Trainable params: 542,723
# Non-trainable params: 4,269,716
# _________________________________________________________________
# Epoch 1/25
# 162/162 [==============================] - 783s 5s/step - loss: 1.1579 - accuracy: 0.6328 - val_loss: 0.6107 - val_accuracy: 0.7376
# Epoch 2/25
# 162/162 [==============================] - 889s 5s/step - loss: 0.6837 - accuracy: 0.7159 - val_loss: 0.5543 - val_accuracy: 0.7748
# Epoch 3/25
# 162/162 [==============================] - 868s 5s/step - loss: 0.6595 - accuracy: 0.7308 - val_loss: 0.5376 - val_accuracy: 0.7771
# Epoch 4/25
# 162/162 [==============================] - 711s 4s/step - loss: 0.6410 - accuracy: 0.7405 - val_loss: 0.5091 - val_accuracy: 0.7918
# Epoch 5/25
# 162/162 [==============================] - 661s 4s/step - loss: 0.6147 - accuracy: 0.7525 - val_loss: 0.5344 - val_accuracy: 0.7817
# Epoch 6/25
# 162/162 [==============================] - 657s 4s/step - loss: 0.6064 - accuracy: 0.7529 - val_loss: 0.6553 - val_accuracy: 0.7307
# Epoch 7/25
# 162/162 [==============================] - 659s 4s/step - loss: 0.6006 - accuracy: 0.7610 - val_loss: 0.5200 - val_accuracy: 0.7771
# Epoch 8/25
# 162/162 [==============================] - 712s 4s/step - loss: 0.5871 - accuracy: 0.7681 - val_loss: 0.5593 - val_accuracy: 0.7779
# Epoch 9/25
# 162/162 [==============================] - 707s 4s/step - loss: 0.5718 - accuracy: 0.7662 - val_loss: 0.5126 - val_accuracy: 0.7957
# Epoch 10/25
# 162/162 [==============================] - 697s 4s/step - loss: 0.5547 - accuracy: 0.7788 - val_loss: 0.4948 - val_accuracy: 0.7957
# Epoch 11/25
# 162/162 [==============================] - 667s 4s/step - loss: 0.5720 - accuracy: 0.7749 - val_loss: 0.4972 - val_accuracy: 0.8088
# Epoch 12/25
# 162/162 [==============================] - 669s 4s/step - loss: 0.5496 - accuracy: 0.7819 - val_loss: 0.5317 - val_accuracy: 0.7724
# Epoch 13/25
# 162/162 [==============================] - 678s 4s/step - loss: 0.5525 - accuracy: 0.7908 - val_loss: 0.5016 - val_accuracy: 0.8019
# Epoch 14/25
# 162/162 [==============================] - 675s 4s/step - loss: 0.5647 - accuracy: 0.7745 - val_loss: 0.5682 - val_accuracy: 0.7585
# Epoch 15/25
# 162/162 [==============================] - 670s 4s/step - loss: 0.5528 - accuracy: 0.7822 - val_loss: 0.5021 - val_accuracy: 0.7918
# Epoch 16/25
# 162/162 [==============================] - 673s 4s/step - loss: 0.5690 - accuracy: 0.7749 - val_loss: 0.4693 - val_accuracy: 0.8150
# Epoch 17/25
# 162/162 [==============================] - 674s 4s/step - loss: 0.5360 - accuracy: 0.7913 - val_loss: 0.5339 - val_accuracy: 0.7949
# Epoch 18/25
# 162/162 [==============================] - 673s 4s/step - loss: 0.5439 - accuracy: 0.7873 - val_loss: 0.4779 - val_accuracy: 0.8111
# Epoch 19/25
# 162/162 [==============================] - 682s 4s/step - loss: 0.5409 - accuracy: 0.7873 - val_loss: 0.4767 - val_accuracy: 0.8057
# Epoch 20/25
# 162/162 [==============================] - 670s 4s/step - loss: 0.5327 - accuracy: 0.7923 - val_loss: 0.4667 - val_accuracy: 0.8228
# Epoch 21/25
# 162/162 [==============================] - 670s 4s/step - loss: 0.5360 - accuracy: 0.7925 - val_loss: 0.5074 - val_accuracy: 0.8096
# Epoch 22/25
# 162/162 [==============================] - 675s 4s/step - loss: 0.5220 - accuracy: 0.7913 - val_loss: 0.6206 - val_accuracy: 0.7423
# Epoch 23/25
# 162/162 [==============================] - 671s 4s/step - loss: 0.5255 - accuracy: 0.7909 - val_loss: 0.4712 - val_accuracy: 0.7949
# Epoch 24/25
# 162/162 [==============================] - 671s 4s/step - loss: 0.5343 - accuracy: 0.7892 - val_loss: 0.4621 - val_accuracy: 0.8251
# Epoch 25/25
# 162/162 [==============================] - 670s 4s/step - loss: 0.5200 - accuracy: 0.7998 - val_loss: 0.4738 - val_accuracy: 0.7980

# %%
import matplotlib.pyplot as plt

fig1 = plt.gcf()

plt.figure(figsize=(10,5))

plt.plot(graph.history['accuracy'])
plt.plot(graph.history['val_accuracy'])

# plt.axis(ymin=0.4, ymax=1)
plt.grid()

plt.title('NASNet Mobile Accuracy for COVID-19 Dataset')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','validation'])

plt.show()

# %%
max_acc = max(graph.history['val_accuracy'])

print('The highest accuracy achieved using NASNet Mobile model is',max_acc*100)
# Out:
# The highest accuracy achieved using NASNet Mobile model is 82.50774145126343
