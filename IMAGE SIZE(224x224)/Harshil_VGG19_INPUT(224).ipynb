# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D, AveragePooling2D
from keras.layers.merge import concatenate

from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Flatten, Dense
from keras.layers import Activation
from keras.layers import BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
from tensorflow import keras

# %%
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import SGD
import cv2, numpy as np

# %%
train_datagen_with_aug = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,
                                   shear_range=0.2,
                                   zoom_range=[0.2,0.5],
                                   width_shift_range = 0.3,
                                   height_shift_range = 0.3,
                                   validation_split=0.2)

train_generator = train_datagen_with_aug.flow_from_directory(
    r'D:\My Work\Baranidharan Sir Research\cnn_xrays_images',
    target_size=(224, 224),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='training'
    ) # set as training data

validation_generator = train_datagen_with_aug.flow_from_directory(
    r'D:\My Work\Baranidharan Sir Research\cnn_xrays_images', # same directory as training data
    target_size=(224, 224),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='validation'
    ) # set as validation data

input_img = Input(shape=(224, 224, 3))
# Out:
# Found 5121 images belonging to 3 classes.
# Found 1278 images belonging to 3 classes.

# %%
from keras.applications import VGG19

VGG_19_MODEL = Sequential()

vgg19 = keras.applications.vgg19.VGG19(
    include_top=False, weights='imagenet', input_tensor=None,
    input_shape=(224,224,3), pooling='max', classes=3,
    classifier_activation='softmax'
)

for layer in vgg19.layers:
    layer.trainable = False 
    
VGG_19_MODEL.add(vgg19)
VGG_19_MODEL.add(Flatten())
VGG_19_MODEL.add(Dense(512,activation='relu'))
VGG_19_MODEL.add(Dense(3, activation='softmax'))

VGG_19_MODEL.summary()

sgd = SGD(learning_rate=0.001, momentum=0.9)

VGG_19_MODEL.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

graph = VGG_19_MODEL.fit(train_generator, validation_data=validation_generator, epochs=25)

graph
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 3s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 512)               20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 20,288,579
# Trainable params: 264,195
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Epoch 1/25
# 161/161 [==============================] - 824s 5s/step - loss: 0.9999 - accuracy: 0.5013 - val_loss: 1.0577 - val_accuracy: 0.4828
# Epoch 2/25
# 161/161 [==============================] - 835s 5s/step - loss: 0.9447 - accuracy: 0.5520 - val_loss: 0.9002 - val_accuracy: 0.5782
# Epoch 3/25
# 161/161 [==============================] - 834s 5s/step - loss: 0.9098 - accuracy: 0.5739 - val_loss: 0.8859 - val_accuracy: 0.5728
# Epoch 4/25
# 161/161 [==============================] - 837s 5s/step - loss: 0.9130 - accuracy: 0.5663 - val_loss: 0.8898 - val_accuracy: 0.5970
# Epoch 5/25
# 161/161 [==============================] - 833s 5s/step - loss: 0.8924 - accuracy: 0.5905 - val_loss: 0.8494 - val_accuracy: 0.6025
# Epoch 6/25
# 161/161 [==============================] - 834s 5s/step - loss: 0.8888 - accuracy: 0.5899 - val_loss: 0.8474 - val_accuracy: 0.6244
# Epoch 7/25
# 161/161 [==============================] - 832s 5s/step - loss: 0.8907 - accuracy: 0.5860 - val_loss: 0.9500 - val_accuracy: 0.5250
# Epoch 8/25
# 161/161 [==============================] - 832s 5s/step - loss: 0.8697 - accuracy: 0.6007 - val_loss: 0.8416 - val_accuracy: 0.6095
# Epoch 9/25
# 161/161 [==============================] - 833s 5s/step - loss: 0.8587 - accuracy: 0.6020 - val_loss: 0.9208 - val_accuracy: 0.5501
# Epoch 10/25
# 161/161 [==============================] - 831s 5s/step - loss: 0.8613 - accuracy: 0.6044 - val_loss: 0.8544 - val_accuracy: 0.5939
# Epoch 11/25
# 161/161 [==============================] - 831s 5s/step - loss: 0.8486 - accuracy: 0.6198 - val_loss: 0.8191 - val_accuracy: 0.6103
# Epoch 12/25
# 161/161 [==============================] - 829s 5s/step - loss: 0.8511 - accuracy: 0.6106 - val_loss: 0.8346 - val_accuracy: 0.5923
# Epoch 13/25
# 161/161 [==============================] - 826s 5s/step - loss: 0.8267 - accuracy: 0.6272 - val_loss: 0.8106 - val_accuracy: 0.6127
# Epoch 14/25
# 161/161 [==============================] - 825s 5s/step - loss: 0.8361 - accuracy: 0.6219 - val_loss: 0.8484 - val_accuracy: 0.6174
# Epoch 15/25
# 161/161 [==============================] - 827s 5s/step - loss: 0.8146 - accuracy: 0.6401 - val_loss: 0.8100 - val_accuracy: 0.6448
# Epoch 16/25
# 161/161 [==============================] - 827s 5s/step - loss: 0.8172 - accuracy: 0.6323 - val_loss: 0.8257 - val_accuracy: 0.6275
# Epoch 17/25
# 161/161 [==============================] - 827s 5s/step - loss: 0.8049 - accuracy: 0.6364 - val_loss: 0.7884 - val_accuracy: 0.6338
# Epoch 18/25
# 161/161 [==============================] - 828s 5s/step - loss: 0.8106 - accuracy: 0.6409 - val_loss: 0.7729 - val_accuracy: 0.6800
# Epoch 19/25
# 161/161 [==============================] - 879s 5s/step - loss: 0.8142 - accuracy: 0.6426 - val_loss: 0.8000 - val_accuracy: 0.6518
# Epoch 20/25
# 161/161 [==============================] - 897s 6s/step - loss: 0.8129 - accuracy: 0.6360 - val_loss: 0.7835 - val_accuracy: 0.6604
# Epoch 21/25
# 161/161 [==============================] - 837s 5s/step - loss: 0.8004 - accuracy: 0.6469 - val_loss: 0.7965 - val_accuracy: 0.6526
# Epoch 22/25
# 161/161 [==============================] - 826s 5s/step - loss: 0.7987 - accuracy: 0.6407 - val_loss: 0.7515 - val_accuracy: 0.6761
# Epoch 23/25
# 161/161 [==============================] - 823s 5s/step - loss: 0.7954 - accuracy: 0.6491 - val_loss: 0.7786 - val_accuracy: 0.6471
# Epoch 24/25
# 161/161 [==============================] - 819s 5s/step - loss: 0.7935 - accuracy: 0.6571 - val_loss: 0.7472 - val_accuracy: 0.6815
# Epoch 25/25
# 161/161 [==============================] - 821s 5s/step - loss: 0.7775 - accuracy: 0.6610 - val_loss: 0.7670 - val_accuracy: 0.6831

# %%
import matplotlib.pyplot as plt

fig1 = plt.gcf()

plt.plot(graph.history['accuracy'])
plt.plot(graph.history['val_accuracy'])

# plt.axis(ymin=0.4, ymax=1)
plt.grid()

plt.title('VGG19 Accuracy for COVID-19 Dataset')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','validation'])

plt.show()
