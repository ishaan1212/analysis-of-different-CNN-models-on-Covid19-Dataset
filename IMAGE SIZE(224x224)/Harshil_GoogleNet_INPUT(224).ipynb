# %% [markdown]
# ## Testing GPU configuration (CuDNN)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from tensorflow import keras

# %%
print('Number of GPUs:', len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Number of GPUs: 1

# %%
tf.test.is_built_with_cuda()
# Out:
# True

# %%
tf.test.is_built_with_gpu_support()
# Out:
# True

# %% [markdown]
# ## Importing necessary libraries

# %%
import keras
from tensorflow.keras.layers import Layer
import keras.backend as K
import tensorflow as tf

# %%
import cv2
import numpy as np
from keras.utils import np_utils
from tensorflow.keras import initializers

# %%
import math
from tensorflow.keras.optimizers import SGD
from keras.callbacks import LearningRateScheduler

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D, AveragePooling2D, Dropout, GlobalAveragePooling2D
from keras.layers.merge import concatenate

from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Flatten, Dense 
from keras.layers import BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# ## Loading the dataset

# %%
  train_datagen_with_aug = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,
                                   shear_range=0.2,
                                   zoom_range=[0.2,0.5],
                                   width_shift_range = 0.3,
                                   height_shift_range = 0.3,
                                   validation_split=0.2)

train_generator = train_datagen_with_aug.flow_from_directory(
    r'/content/drive/My Drive/X-Ray Images Dataset for research project',
    target_size=(224, 224),
    batch_size=16,
    color_mode='grayscale',
    class_mode='categorical',
    subset='training'
    ) # set as training data

validation_generator = train_datagen_with_aug.flow_from_directory(
    r'/content/drive/My Drive/X-Ray Images Dataset for research project', # same directory as training data
    target_size=(224, 224),
    batch_size=16,
    color_mode='grayscale',
    class_mode='categorical',
    subset='validation'
    ) # set as validation data

input_img = Input(shape=(224, 224, 1))
# Out:
# Found 5171 images belonging to 3 classes.
# Found 1292 images belonging to 3 classes.

# %% [markdown]
# ## Constructing the Architecture

# %%
# kernel_init = keras.initializers.glorot_uniform()
# bias_init = keras.initializers.Constant(value=0.2)

# %%
def inception_module(x,
                     filters_1x1,
                     filters_3x3_reduce,
                     filters_3x3,
                     filters_5x5_reduce,
                     filters_5x5,
                     filters_pool_proj,
                     name=None):
    
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu')(x)
    
    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu')(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu')(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu')(x)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu')(conv_5x5)

    pool_proj = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu')(pool_proj)

    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=3, name=name)
    
    return output

# %%
input_layer = Input(shape=(224, 224, 1))

# x = Conv2D(64, (7, 7), padding='valid', strides=(2, 2), activation='relu', name='conv_1_7x7/2', kernel_initializer=kernel_init, bias_initializer=bias_init)(input_layer)
x = Conv2D(64, (7, 7), padding='valid', strides=(2, 2), activation='relu', name='conv_1_7x7/2')(input_layer)
x = MaxPooling2D((3, 3), padding='valid', strides=(2, 2), name='max_pool_1_3x3/2')(x)
x = Conv2D(64, (1, 1), padding='valid', strides=(1, 1), activation='relu', name='conv_2a_3x3/1')(x)
x = Conv2D(192, (3, 3), padding='valid', strides=(1, 1), activation='relu', name='conv_2b_3x3/1')(x)
x = MaxPooling2D((3, 3), padding='valid', strides=(2, 2), name='max_pool_2_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=64,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_3a')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=192,
                     filters_5x5_reduce=32,
                     filters_5x5=96,
                     filters_pool_proj=64,
                     name='inception_3b')

x = MaxPooling2D((3, 3), padding='valid', strides=(2, 2), name='max_pool_3_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=192,
                     filters_3x3_reduce=96,
                     filters_3x3=208,
                     filters_5x5_reduce=16,
                     filters_5x5=48,
                     filters_pool_proj=64,
                     name='inception_4a')


x1 = AveragePooling2D((5, 5), strides=3)(x)
x1 = Conv2D(128, (1, 1), padding='valid', activation='relu')(x1)
x1 = Flatten()(x1)
x1 = Dense(1024, activation='relu')(x1)
x1 = Dropout(0.7)(x1)
x1 = Dense(3, activation='softmax', name='auxilliary_output_1')(x1)

x = inception_module(x,
                     filters_1x1=160,
                     filters_3x3_reduce=112,
                     filters_3x3=224,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4b')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=256,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4c')

x = inception_module(x,
                     filters_1x1=112,
                     filters_3x3_reduce=144,
                     filters_3x3=288,
                     filters_5x5_reduce=32,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4d')


x2 = AveragePooling2D((5, 5), strides=3)(x)
x2 = Conv2D(128, (1, 1), padding='valid', activation='relu')(x2)
x2 = Flatten()(x2)
x2 = Dense(1024, activation='relu')(x2)
x2 = Dropout(0.7)(x2)
x2 = Dense(3, activation='softmax', name='auxilliary_output_2')(x2)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_4e')

x = MaxPooling2D((3, 3), padding='valid', strides=(2, 2), name='max_pool_4_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5a')

x = inception_module(x,
                     filters_1x1=384,
                     filters_3x3_reduce=192,
                     filters_3x3=384,
                     filters_5x5_reduce=48,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5b')

x = GlobalAveragePooling2D(name='avg_pool_5_3x3/1')(x)

x = Dropout(0.4)(x)

x = Dense(3, activation='softmax', name='output')(x)

# %%
model = Model(input_layer, [x, x1, x2], name='inception_v1')

# %%
model.summary()
# Out:
# Model: "inception_v1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 1  0           []
#                                 )]
#
#  conv_1_7x7/2 (Conv2D)          (None, 109, 109, 64  3200        ['input_3[0][0]']
#                                 )
#
#  max_pool_1_3x3/2 (MaxPooling2D  (None, 54, 54, 64)  0           ['conv_1_7x7/2[0][0]']
#  )
#
#  conv_2a_3x3/1 (Conv2D)         (None, 54, 54, 64)   4160        ['max_pool_1_3x3/2[0][0]']
#
#  conv_2b_3x3/1 (Conv2D)         (None, 52, 52, 192)  110784      ['conv_2a_3x3/1[0][0]']
#
#  max_pool_2_3x3/2 (MaxPooling2D  (None, 25, 25, 192)  0          ['conv_2b_3x3/1[0][0]']
#  )
#
#  conv2d_1 (Conv2D)              (None, 25, 25, 96)   18528       ['max_pool_2_3x3/2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 25, 25, 16)   3088        ['max_pool_2_3x3/2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 25, 25, 192)  0           ['max_pool_2_3x3/2[0][0]']
#
#  conv2d (Conv2D)                (None, 25, 25, 64)   12352       ['max_pool_2_3x3/2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 25, 25, 128)  110720      ['conv2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 25, 25, 32)   12832       ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 25, 25, 32)   6176        ['max_pooling2d[0][0]']
#
#  inception_3a (Concatenate)     (None, 25, 25, 256)  0           ['conv2d[0][0]',
#                                                                   'conv2d_2[0][0]',
#                                                                   'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 25, 25, 128)  32896       ['inception_3a[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 25, 25, 32)   8224        ['inception_3a[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 25, 25, 256)  0          ['inception_3a[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 25, 25, 128)  32896       ['inception_3a[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 25, 25, 192)  221376      ['conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 25, 25, 96)   76896       ['conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 25, 25, 64)   16448       ['max_pooling2d_1[0][0]']
#
#  inception_3b (Concatenate)     (None, 25, 25, 480)  0           ['conv2d_6[0][0]',
#                                                                   'conv2d_8[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  max_pool_3_3x3/2 (MaxPooling2D  (None, 12, 12, 480)  0          ['inception_3b[0][0]']
#  )
#
#  conv2d_13 (Conv2D)             (None, 12, 12, 96)   46176       ['max_pool_3_3x3/2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 12, 12, 16)   7696        ['max_pool_3_3x3/2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 480)  0          ['max_pool_3_3x3/2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 12, 12, 192)  92352       ['max_pool_3_3x3/2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 12, 12, 208)  179920      ['conv2d_13[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 12, 12, 48)   19248       ['conv2d_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 12, 12, 64)   30784       ['max_pooling2d_2[0][0]']
#
#  inception_4a (Concatenate)     (None, 12, 12, 512)  0           ['conv2d_12[0][0]',
#                                                                   'conv2d_14[0][0]',
#                                                                   'conv2d_16[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 12, 12, 112)  57456       ['inception_4a[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 12, 12, 24)   12312       ['inception_4a[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 512)  0          ['inception_4a[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 12, 12, 160)  82080       ['inception_4a[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 12, 12, 224)  226016      ['conv2d_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 12, 12, 64)   38464       ['conv2d_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 12, 12, 64)   32832       ['max_pooling2d_3[0][0]']
#
#  inception_4b (Concatenate)     (None, 12, 12, 512)  0           ['conv2d_19[0][0]',
#                                                                   'conv2d_21[0][0]',
#                                                                   'conv2d_23[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 12, 12, 128)  65664       ['inception_4b[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 12, 12, 24)   12312       ['inception_4b[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 512)  0          ['inception_4b[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 12, 12, 128)  65664       ['inception_4b[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 12, 12, 256)  295168      ['conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 12, 12, 64)   38464       ['conv2d_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 12, 12, 64)   32832       ['max_pooling2d_4[0][0]']
#
#  inception_4c (Concatenate)     (None, 12, 12, 512)  0           ['conv2d_25[0][0]',
#                                                                   'conv2d_27[0][0]',
#                                                                   'conv2d_29[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 12, 12, 144)  73872       ['inception_4c[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 12, 12, 32)   16416       ['inception_4c[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 12, 12, 512)  0          ['inception_4c[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 12, 12, 112)  57456       ['inception_4c[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 12, 12, 288)  373536      ['conv2d_32[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 12, 12, 64)   51264       ['conv2d_34[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 12, 12, 64)   32832       ['max_pooling2d_5[0][0]']
#
#  inception_4d (Concatenate)     (None, 12, 12, 528)  0           ['conv2d_31[0][0]',
#                                                                   'conv2d_33[0][0]',
#                                                                   'conv2d_35[0][0]',
#                                                                   'conv2d_36[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 12, 12, 160)  84640       ['inception_4d[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 12, 12, 32)   16928       ['inception_4d[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 12, 12, 528)  0          ['inception_4d[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 12, 12, 256)  135424      ['inception_4d[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 12, 12, 320)  461120      ['conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 12, 12, 128)  102528      ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 12, 12, 128)  67712       ['max_pooling2d_6[0][0]']
#
#  inception_4e (Concatenate)     (None, 12, 12, 832)  0           ['conv2d_38[0][0]',
#                                                                   'conv2d_40[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_43[0][0]']
#
#  max_pool_4_3x3/2 (MaxPooling2D  (None, 5, 5, 832)   0           ['inception_4e[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 5, 5, 160)    133280      ['max_pool_4_3x3/2[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 5, 5, 32)     26656       ['max_pool_4_3x3/2[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 5, 5, 832)   0           ['max_pool_4_3x3/2[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 5, 5, 256)    213248      ['max_pool_4_3x3/2[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 5, 5, 320)    461120      ['conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 5, 5, 128)    102528      ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 5, 5, 128)    106624      ['max_pooling2d_7[0][0]']
#
#  inception_5a (Concatenate)     (None, 5, 5, 832)    0           ['conv2d_44[0][0]',
#                                                                   'conv2d_46[0][0]',
#                                                                   'conv2d_48[0][0]',
#                                                                   'conv2d_49[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 5, 5, 192)    159936      ['inception_5a[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 5, 5, 48)     39984       ['inception_5a[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 5, 5, 832)   0           ['inception_5a[0][0]']
#
#  average_pooling2d (AveragePool  (None, 3, 3, 512)   0           ['inception_4a[0][0]']
#  ing2D)
#
#  average_pooling2d_1 (AveragePo  (None, 3, 3, 528)   0           ['inception_4d[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 5, 5, 384)    319872      ['inception_5a[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 5, 5, 384)    663936      ['conv2d_51[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 5, 5, 128)    153728      ['conv2d_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 5, 5, 128)    106624      ['max_pooling2d_8[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 3, 3, 128)    65664       ['average_pooling2d[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 3, 3, 128)    67712       ['average_pooling2d_1[0][0]']
#
#  inception_5b (Concatenate)     (None, 5, 5, 1024)   0           ['conv2d_50[0][0]',
#                                                                   'conv2d_52[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  flatten (Flatten)              (None, 1152)         0           ['conv2d_18[0][0]']
#
#  flatten_1 (Flatten)            (None, 1152)         0           ['conv2d_37[0][0]']
#
#  avg_pool_5_3x3/1 (GlobalAverag  (None, 1024)        0           ['inception_5b[0][0]']
#  ePooling2D)
#
#  dense (Dense)                  (None, 1024)         1180672     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 1024)         1180672     ['flatten_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 1024)         0           ['avg_pool_5_3x3/1[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_1[0][0]']
#
#  output (Dense)                 (None, 3)            3075        ['dropout_2[0][0]']
#
#  auxilliary_output_1 (Dense)    (None, 3)            3075        ['dropout[0][0]']
#
#  auxilliary_output_2 (Dense)    (None, 3)            3075        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 8,471,225
# Trainable params: 8,471,225
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 25
initial_lrate = 0.01

def decay(epoch, steps=100):
    initial_lrate = 0.01
    drop = 0.96
    epochs_drop = 8
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

sgd = SGD(learning_rate=initial_lrate, momentum=0.9, nesterov=False)

lr_sc = LearningRateScheduler(decay, verbose=1)

model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'], loss_weights=[1, 0.3, 0.3], optimizer=sgd, metrics=['accuracy'])

# %%
graph = model.fit(train_generator, epochs=epochs, validation_data=validation_generator)

graph
# Out:
# Epoch 1/25
# 324/324 [==============================] - 1450s 4s/step - loss: 1.7174 - output_loss: 1.0735 - auxilliary_output_1_loss: 1.0722 - auxilliary_output_2_loss: 1.0739 - output_accuracy: 0.3802 - auxilliary_output_1_accuracy: 0.3800 - auxilliary_output_2_accuracy: 0.3817 - val_loss: 1.7095 - val_output_loss: 1.0698 - val_auxilliary_output_1_loss: 1.0637 - val_auxilliary_output_2_loss: 1.0686 - val_output_accuracy: 0.3870 - val_auxilliary_output_1_accuracy: 0.3947 - val_auxilliary_output_2_accuracy: 0.3870
# Epoch 2/25
# 324/324 [==============================] - 235s 726ms/step - loss: 1.7146 - output_loss: 1.0726 - auxilliary_output_1_loss: 1.0691 - auxilliary_output_2_loss: 1.0711 - output_accuracy: 0.3957 - auxilliary_output_1_accuracy: 0.4042 - auxilliary_output_2_accuracy: 0.3910 - val_loss: 1.6994 - val_output_loss: 1.0642 - val_auxilliary_output_1_loss: 1.0557 - val_auxilliary_output_2_loss: 1.0615 - val_output_accuracy: 0.3893 - val_auxilliary_output_1_accuracy: 0.3901 - val_auxilliary_output_2_accuracy: 0.3901
# Epoch 3/25
# 324/324 [==============================] - 230s 709ms/step - loss: 1.6943 - output_loss: 1.0581 - auxilliary_output_1_loss: 1.0603 - auxilliary_output_2_loss: 1.0604 - output_accuracy: 0.4442 - auxilliary_output_1_accuracy: 0.4376 - auxilliary_output_2_accuracy: 0.4351 - val_loss: 1.6880 - val_output_loss: 1.0581 - val_auxilliary_output_1_loss: 1.0450 - val_auxilliary_output_2_loss: 1.0548 - val_output_accuracy: 0.3870 - val_auxilliary_output_1_accuracy: 0.3916 - val_auxilliary_output_2_accuracy: 0.3893
# Epoch 21/25
# 324/324 [==============================] - 228s 703ms/step - loss: 1.0674 - output_loss: 0.6624 - auxilliary_output_1_loss: 0.6858 - auxilliary_output_2_loss: 0.6642 - output_accuracy: 0.7354 - auxilliary_output_1_accuracy: 0.7237 - auxilliary_output_2_accuracy: 0.7291 - val_loss: 1.1088 - val_output_loss: 0.6863 - val_auxilliary_output_1_loss: 0.7267 - val_auxilliary_output_2_loss: 0.6819 - val_output_accuracy: 0.6811 - val_auxilliary_output_1_accuracy: 0.6455 - val_auxilliary_output_2_accuracy: 0.6842
# Epoch 22/25
# 324/324 [==============================] - 224s 691ms/step - loss: 1.0036 - output_loss: 0.6188 - auxilliary_output_1_loss: 0.6524 - auxilliary_output_2_loss: 0.6303 - output_accuracy: 0.7548 - auxilliary_output_1_accuracy: 0.7467 - auxilliary_output_2_accuracy: 0.7521 - val_loss: 0.9433 - val_output_loss: 0.5856 - val_auxilliary_output_1_loss: 0.6015 - val_auxilliary_output_2_loss: 0.5911 - val_output_accuracy: 0.7570 - val_auxilliary_output_1_accuracy: 0.7570 - val_auxilliary_output_2_accuracy: 0.7539
# Epoch 23/25
# 324/324 [==============================] - 234s 724ms/step - loss: 1.0230 - output_loss: 0.6348 - auxilliary_output_1_loss: 0.6530 - auxilliary_output_2_loss: 0.6412 - output_accuracy: 0.7515 - auxilliary_output_1_accuracy: 0.7405 - auxilliary_output_2_accuracy: 0.7482 - val_loss: 1.0483 - val_output_loss: 0.6459 - val_auxilliary_output_1_loss: 0.6982 - val_auxilliary_output_2_loss: 0.6433 - val_output_accuracy: 0.7330 - val_auxilliary_output_1_accuracy: 0.6881 - val_auxilliary_output_2_accuracy: 0.7221
# Epoch 24/25
# 324/324 [==============================] - 233s 720ms/step - loss: 1.0483 - output_loss: 0.6519 - auxilliary_output_1_loss: 0.6680 - auxilliary_output_2_loss: 0.6533 - output_accuracy: 0.7424 - auxilliary_output_1_accuracy: 0.7382 - auxilliary_output_2_accuracy: 0.7438 - val_loss: 1.1783 - val_output_loss: 0.7463 - val_auxilliary_output_1_loss: 0.7061 - val_auxilliary_output_2_loss: 0.7340 - val_output_accuracy: 0.6858 - val_auxilliary_output_1_accuracy: 0.7051 - val_auxilliary_output_2_accuracy: 0.6834
# Epoch 25/25
# 324/324 [==============================] - 230s 711ms/step - loss: 0.9801 - output_loss: 0.6056 - auxilliary_output_1_loss: 0.6386 - auxilliary_output_2_loss: 0.6098 - output_accuracy: 0.7633 - auxilliary_output_1_accuracy: 0.7501 - auxilliary_output_2_accuracy: 0.7625 - val_loss: 0.9376 - val_output_loss: 0.5919 - val_auxilliary_output_1_loss: 0.5625 - val_auxilliary_output_2_loss: 0.5897 - val_output_accuracy: 0.7794 - val_auxilliary_output_1_accuracy: 0.7941 - val_auxilliary_output_2_accuracy: 0.7895

# %%
max_acc = max(graph.history['val_output_accuracy'])

print('The highest accuracy achieved using GoogleNet with input: 224x224 is',max_acc*100)
# Out:
# The highest accuracy achieved using GoogleNet with input: 224x224 is 78.79257202148438
