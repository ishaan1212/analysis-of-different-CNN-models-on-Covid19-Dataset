# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D, AveragePooling2D
from keras.layers.merge import concatenate

from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Flatten, Dense
from keras.layers import Activation
from keras.layers import BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping

from tensorflow import keras

from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import SGD
import cv2, numpy as np

# %%
train_datagen_with_aug = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,
                                   shear_range=0.2,
                                   zoom_range=[0.2,0.5],
                                   width_shift_range = 0.3,
                                   height_shift_range = 0.3,
                                   validation_split=0.2)

train_generator = train_datagen_with_aug.flow_from_directory(
    r'D:\My Work\Baranidharan Sir Research\cnn_xrays_images',
    target_size=(224, 224),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='training'
    ) # set as training data

validation_generator = train_datagen_with_aug.flow_from_directory(
    r'D:\My Work\Baranidharan Sir Research\cnn_xrays_images', # same directory as training data
    target_size=(224, 224),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='validation'
    ) # set as validation data

input_img = Input(shape=(224, 224, 3))
# Out:
# Found 5121 images belonging to 3 classes.
# Found 1278 images belonging to 3 classes.

# %%
from keras.applications import xception

XCEPTION = Sequential()

xception_model = keras.applications.xception.Xception(
    include_top=False, weights='imagenet',
    input_shape=(224,224,3), pooling='max', classes=3,
    classifier_activation='softmax'
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 3s 0us/step

# %%
for layer in xception_model.layers:
    layer.trainable = False
    
XCEPTION.add(xception_model)
XCEPTION.add(Flatten())
XCEPTION.add(Dense(512,activation='relu'))
XCEPTION.add(Dense(3, activation='softmax'))

XCEPTION.summary()

Adam = keras.optimizers.Adam(learning_rate=0.001)
XCEPTION.compile(optimizer=Adam, loss='categorical_crossentropy', metrics=['accuracy'])

graph = XCEPTION.fit(train_generator, epochs=25, validation_data = validation_generator)

graph
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Functional)        (None, 2048)              20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 21,912,107
# Trainable params: 1,050,627
# Non-trainable params: 20,861,480
# _________________________________________________________________
# Epoch 1/25
# 161/161 [==============================] - 480s 3s/step - loss: 0.8638 - accuracy: 0.6645 - val_loss: 0.5593 - val_accuracy: 0.7567
# Epoch 2/25
# 161/161 [==============================] - 404s 3s/step - loss: 0.6222 - accuracy: 0.7424 - val_loss: 0.5602 - val_accuracy: 0.7825
# Epoch 3/25
# 161/161 [==============================] - 395s 2s/step - loss: 0.5590 - accuracy: 0.7786 - val_loss: 0.5141 - val_accuracy: 0.7958
# Epoch 4/25
# 161/161 [==============================] - 395s 2s/step - loss: 0.5655 - accuracy: 0.7805 - val_loss: 0.4738 - val_accuracy: 0.8169
# Epoch 5/25
# 161/161 [==============================] - 396s 2s/step - loss: 0.5490 - accuracy: 0.7776 - val_loss: 0.5268 - val_accuracy: 0.7817
# Epoch 6/25
# 161/161 [==============================] - 398s 2s/step - loss: 0.5344 - accuracy: 0.7877 - val_loss: 0.4538 - val_accuracy: 0.8216
# Epoch 7/25
# 161/161 [==============================] - 397s 2s/step - loss: 0.5143 - accuracy: 0.7987 - val_loss: 0.4452 - val_accuracy: 0.8279
# Epoch 8/25
# 161/161 [==============================] - 403s 3s/step - loss: 0.5112 - accuracy: 0.8041 - val_loss: 0.4933 - val_accuracy: 0.8083
# Epoch 9/25
# 161/161 [==============================] - 400s 2s/step - loss: 0.5024 - accuracy: 0.8108 - val_loss: 0.4303 - val_accuracy: 0.8286
# Epoch 10/25
# 161/161 [==============================] - 403s 3s/step - loss: 0.5074 - accuracy: 0.7957 - val_loss: 0.4667 - val_accuracy: 0.8106
# Epoch 11/25
# 161/161 [==============================] - 401s 2s/step - loss: 0.5027 - accuracy: 0.8024 - val_loss: 0.4363 - val_accuracy: 0.8216
# Epoch 12/25
# 161/161 [==============================] - 401s 2s/step - loss: 0.5153 - accuracy: 0.7934 - val_loss: 0.4307 - val_accuracy: 0.8271
# Epoch 13/25
# 161/161 [==============================] - 401s 2s/step - loss: 0.5399 - accuracy: 0.7899 - val_loss: 0.4568 - val_accuracy: 0.8067
# Epoch 14/25
# 161/161 [==============================] - 404s 3s/step - loss: 0.4980 - accuracy: 0.8102 - val_loss: 0.4775 - val_accuracy: 0.8044
# Epoch 15/25
# 161/161 [==============================] - 403s 3s/step - loss: 0.4711 - accuracy: 0.8153 - val_loss: 0.5017 - val_accuracy: 0.8005
# Epoch 16/25
# 161/161 [==============================] - 404s 3s/step - loss: 0.5066 - accuracy: 0.8006 - val_loss: 0.4530 - val_accuracy: 0.8169
# Epoch 17/25
# 161/161 [==============================] - 407s 3s/step - loss: 0.4922 - accuracy: 0.8104 - val_loss: 0.4068 - val_accuracy: 0.8412
# Epoch 18/25
# 161/161 [==============================] - 402s 2s/step - loss: 0.4823 - accuracy: 0.8135 - val_loss: 0.4372 - val_accuracy: 0.8279
# Epoch 19/25
# 161/161 [==============================] - 404s 3s/step - loss: 0.4601 - accuracy: 0.8282 - val_loss: 0.4596 - val_accuracy: 0.8161
# Epoch 20/25
# 161/161 [==============================] - 422s 3s/step - loss: 0.4682 - accuracy: 0.8223 - val_loss: 0.4197 - val_accuracy: 0.8372
# Epoch 21/25
# 161/161 [==============================] - 423s 3s/step - loss: 0.4699 - accuracy: 0.8231 - val_loss: 0.4164 - val_accuracy: 0.8443
# Epoch 22/25
# 161/161 [==============================] - 423s 3s/step - loss: 0.4647 - accuracy: 0.8198 - val_loss: 0.3870 - val_accuracy: 0.8623
# Epoch 23/25
# 161/161 [==============================] - 425s 3s/step - loss: 0.4585 - accuracy: 0.8264 - val_loss: 0.4379 - val_accuracy: 0.8326
# Epoch 24/25
# 161/161 [==============================] - 425s 3s/step - loss: 0.4703 - accuracy: 0.8172 - val_loss: 0.4573 - val_accuracy: 0.8279
# Epoch 25/25
# 161/161 [==============================] - 424s 3s/step - loss: 0.4744 - accuracy: 0.8188 - val_loss: 0.4102 - val_accuracy: 0.8404

# %%
import matplotlib.pyplot as plt

fig1 = plt.gcf()

plt.plot(graph.history['accuracy'])
plt.plot(graph.history['val_accuracy'])

# plt.axis(ymin=0.4, ymax=1)
plt.grid()

plt.title('VGG19 Accuracy for COVID-19 Dataset')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','validation'])

plt.show()
