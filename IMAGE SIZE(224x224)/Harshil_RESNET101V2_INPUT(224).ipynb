# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D, AveragePooling2D
from keras.layers.merge import concatenate

from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Flatten, Dense
from keras.layers import Activation
from keras.layers import BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping

from tensorflow import keras

from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import SGD
import cv2, numpy as np

# %%
train_datagen_with_aug = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,
                                   shear_range=0.2,
                                   zoom_range=[0.2,0.5],
                                   width_shift_range = 0.3,
                                   height_shift_range = 0.3,
                                   validation_split=0.2)

train_generator = train_datagen_with_aug.flow_from_directory(
    r'D:\My Work\Baranidharan Sir Research\cnn_xrays_images',
    target_size=(224, 224),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='training'
    ) # set as training data

validation_generator = train_datagen_with_aug.flow_from_directory(
    r'D:\My Work\Baranidharan Sir Research\cnn_xrays_images', # same directory as training data
    target_size=(224, 224),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='validation'
    ) # set as validation data

input_img = Input(shape=(224, 224, 3))
# Out:
# Found 5121 images belonging to 3 classes.
# Found 1278 images belonging to 3 classes.

# %%
from keras.applications import ResNet101V2

RESNET_101_V2 = Sequential()

resnet101v2_model = keras.applications.resnet_v2.ResNet101V2(
    include_top=False, weights='imagenet',
    input_shape=[224,224,3], pooling='max', classes=3,
    classifier_activation='softmax'
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171319296/171317808 [==============================] - 7s 0us/step

# %%
for layer in resnet101v2_model.layers:
    layer.trainable = False
    
RESNET_101_V2.add(resnet101v2_model)
RESNET_101_V2.add(Flatten())
RESNET_101_V2.add(Dense(512,activation='relu'))
RESNET_101_V2.add(Dense(3, activation='softmax'))

RESNET_101_V2.summary()

Adam = keras.optimizers.Adam(learning_rate=0.001)
RESNET_101_V2.compile(optimizer=Adam, loss='categorical_crossentropy', metrics=['accuracy'])

graph = RESNET_101_V2.fit(train_generator, epochs=25, validation_data = validation_generator)

graph
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet101v2 (Functional)     (None, 2048)              42626560
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 43,677,187
# Trainable params: 1,050,627
# Non-trainable params: 42,626,560
# _________________________________________________________________
# Epoch 1/25
# 161/161 [==============================] - 531s 3s/step - loss: 1.5833 - accuracy: 0.6831 - val_loss: 0.5577 - val_accuracy: 0.7746
# Epoch 2/25
# 161/161 [==============================] - 525s 3s/step - loss: 0.6001 - accuracy: 0.7674 - val_loss: 0.4964 - val_accuracy: 0.8059
# Epoch 3/25
# 161/161 [==============================] - 538s 3s/step - loss: 0.5624 - accuracy: 0.7862 - val_loss: 0.4810 - val_accuracy: 0.8153
# Epoch 4/25
# 161/161 [==============================] - 532s 3s/step - loss: 0.5352 - accuracy: 0.7942 - val_loss: 0.4702 - val_accuracy: 0.8114
# Epoch 5/25
# 161/161 [==============================] - 536s 3s/step - loss: 0.5160 - accuracy: 0.8026 - val_loss: 0.4431 - val_accuracy: 0.8247
# Epoch 6/25
# 161/161 [==============================] - 532s 3s/step - loss: 0.4935 - accuracy: 0.8112 - val_loss: 0.4446 - val_accuracy: 0.8216
# Epoch 7/25
# 161/161 [==============================] - 533s 3s/step - loss: 0.4850 - accuracy: 0.8153 - val_loss: 0.4540 - val_accuracy: 0.8224
# Epoch 8/25
# 161/161 [==============================] - 534s 3s/step - loss: 0.4757 - accuracy: 0.8186 - val_loss: 0.4218 - val_accuracy: 0.8255
# Epoch 9/25
# 161/161 [==============================] - 537s 3s/step - loss: 0.4587 - accuracy: 0.8266 - val_loss: 0.5068 - val_accuracy: 0.8138
# Epoch 10/25
# 161/161 [==============================] - 533s 3s/step - loss: 0.4608 - accuracy: 0.8256 - val_loss: 0.4382 - val_accuracy: 0.8341
# Epoch 11/25
# 161/161 [==============================] - 532s 3s/step - loss: 0.4684 - accuracy: 0.8178 - val_loss: 0.4145 - val_accuracy: 0.8349
# Epoch 12/25
# 161/161 [==============================] - 534s 3s/step - loss: 0.4635 - accuracy: 0.8229 - val_loss: 0.4506 - val_accuracy: 0.8200
# Epoch 13/25
# 161/161 [==============================] - 533s 3s/step - loss: 0.4518 - accuracy: 0.8305 - val_loss: 0.4359 - val_accuracy: 0.8357
# Epoch 14/25
# 161/161 [==============================] - 533s 3s/step - loss: 0.4514 - accuracy: 0.8342 - val_loss: 0.4107 - val_accuracy: 0.8372
# Epoch 15/25
# 161/161 [==============================] - 532s 3s/step - loss: 0.4351 - accuracy: 0.8399 - val_loss: 0.3867 - val_accuracy: 0.8685
# Epoch 16/25
# 161/161 [==============================] - 534s 3s/step - loss: 0.4366 - accuracy: 0.8387 - val_loss: 0.4092 - val_accuracy: 0.8427
# Epoch 17/25
# 161/161 [==============================] - 534s 3s/step - loss: 0.4347 - accuracy: 0.8426 - val_loss: 0.3590 - val_accuracy: 0.8662
# Epoch 18/25
# 161/161 [==============================] - 543s 3s/step - loss: 0.4586 - accuracy: 0.8282 - val_loss: 0.3960 - val_accuracy: 0.8365
# Epoch 19/25
# 161/161 [==============================] - 541s 3s/step - loss: 0.4456 - accuracy: 0.8346 - val_loss: 0.3789 - val_accuracy: 0.8552
# Epoch 20/25
# 161/161 [==============================] - 542s 3s/step - loss: 0.4547 - accuracy: 0.8309 - val_loss: 0.4165 - val_accuracy: 0.8404
# Epoch 21/25
# 161/161 [==============================] - 541s 3s/step - loss: 0.4237 - accuracy: 0.8381 - val_loss: 0.3882 - val_accuracy: 0.8505
# Epoch 22/25
# 161/161 [==============================] - 543s 3s/step - loss: 0.4163 - accuracy: 0.8475 - val_loss: 0.3659 - val_accuracy: 0.8552
# Epoch 23/25
# 161/161 [==============================] - 545s 3s/step - loss: 0.4252 - accuracy: 0.8434 - val_loss: 0.3810 - val_accuracy: 0.8521
# Epoch 24/25
# 161/161 [==============================] - 541s 3s/step - loss: 0.4202 - accuracy: 0.8438 - val_loss: 0.4185 - val_accuracy: 0.8451
# Epoch 25/25
# 161/161 [==============================] - 542s 3s/step - loss: 0.4256 - accuracy: 0.8481 - val_loss: 0.3928 - val_accuracy: 0.8576

# %%
import matplotlib.pyplot as plt

fig1 = plt.gcf()

plt.plot(graph.history['accuracy'])
plt.plot(graph.history['val_accuracy'])

# plt.axis(ymin=0.4, ymax=1)
plt.grid()

plt.title('VGG19 Accuracy for COVID-19 Dataset')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','validation'])

plt.show()
