# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D, AveragePooling2D
from keras.layers.merge import concatenate

from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Flatten, Dense
from keras.layers import Activation
from keras.layers import BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping

from tensorflow import keras

from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import SGD
import cv2, numpy as np

# %%
train_datagen_with_aug = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,
                                   shear_range=0.2,
                                   zoom_range=[0.2,0.5],
                                   width_shift_range = 0.3,
                                   height_shift_range = 0.3,
                                   validation_split=0.2)

train_generator = train_datagen_with_aug.flow_from_directory(
    r'C:\Users\Harshil Bhandari\Pictures\X-Ray Images Dataset for research project',
    target_size=(224, 224),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='training'
    ) # set as training data

validation_generator = train_datagen_with_aug.flow_from_directory(
    r'C:\Users\Harshil Bhandari\Pictures\X-Ray Images Dataset for research project', # same directory as training data
    target_size=(224, 224),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='validation'
    ) # set as validation data

input_img = Input(shape=(224, 224, 3))
# Out:
# Found 5171 images belonging to 3 classes.
# Found 1292 images belonging to 3 classes.

# %%
from keras.applications import densenet

DENSENET = Sequential()

densenet_model = keras.applications.densenet.DenseNet121(
    include_top=False, weights='imagenet',
    input_shape=(224,224,3), pooling='max', classes=3
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 2s 0us/step

# %%
for layer in densenet_model.layers:
    layer.trainable = False
    
DENSENET.add(densenet_model)
DENSENET.add(Flatten())
DENSENET.add(Dense(512,activation='relu'))
DENSENET.add(Dense(3, activation='softmax'))

DENSENET.summary()

Adam = keras.optimizers.Adam(learning_rate=0.001)
DENSENET.compile(optimizer=Adam, loss='categorical_crossentropy', metrics=['accuracy'])

graph = DENSENET.fit(train_generator, epochs=25, validation_data = validation_generator)

graph
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Functional)     (None, 1024)              7037504
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               524800
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 7,563,843
# Trainable params: 526,339
# Non-trainable params: 7,037,504
# _________________________________________________________________
# Epoch 1/25
# 162/162 [==============================] - 708s 4s/step - loss: 0.8816 - accuracy: 0.6643 - val_loss: 0.5425 - val_accuracy: 0.7902
# Epoch 2/25
# 162/162 [==============================] - 706s 4s/step - loss: 0.6232 - accuracy: 0.7517 - val_loss: 0.5413 - val_accuracy: 0.7895
# Epoch 3/25
# 162/162 [==============================] - 790s 5s/step - loss: 0.6089 - accuracy: 0.7590 - val_loss: 0.6198 - val_accuracy: 0.7523
# Epoch 4/25
# 162/162 [==============================] - 862s 5s/step - loss: 0.5956 - accuracy: 0.7629 - val_loss: 0.5687 - val_accuracy: 0.7763
# Epoch 5/25
# 162/162 [==============================] - 786s 5s/step - loss: 0.5484 - accuracy: 0.7892 - val_loss: 0.5984 - val_accuracy: 0.7562
# Epoch 6/25
# 162/162 [==============================] - 692s 4s/step - loss: 0.5496 - accuracy: 0.7892 - val_loss: 0.5113 - val_accuracy: 0.7941
# Epoch 7/25
# 162/162 [==============================] - 693s 4s/step - loss: 0.5448 - accuracy: 0.7877 - val_loss: 0.4614 - val_accuracy: 0.8166
# Epoch 8/25
# 162/162 [==============================] - 697s 4s/step - loss: 0.5319 - accuracy: 0.7940 - val_loss: 0.4201 - val_accuracy: 0.8382
# Epoch 9/25
# 162/162 [==============================] - 694s 4s/step - loss: 0.5110 - accuracy: 0.8124 - val_loss: 0.4873 - val_accuracy: 0.8142
# Epoch 10/25
# 162/162 [==============================] - 692s 4s/step - loss: 0.5275 - accuracy: 0.7948 - val_loss: 0.4683 - val_accuracy: 0.8228
# Epoch 11/25
# 162/162 [==============================] - 655s 4s/step - loss: 0.5217 - accuracy: 0.7969 - val_loss: 0.4517 - val_accuracy: 0.8212
# Epoch 12/25
# 162/162 [==============================] - 658s 4s/step - loss: 0.4956 - accuracy: 0.8089 - val_loss: 0.4417 - val_accuracy: 0.8274
# Epoch 13/25
# 162/162 [==============================] - 653s 4s/step - loss: 0.5005 - accuracy: 0.8107 - val_loss: 0.4444 - val_accuracy: 0.8421
# Epoch 14/25
# 162/162 [==============================] - 667s 4s/step - loss: 0.5032 - accuracy: 0.8082 - val_loss: 0.4391 - val_accuracy: 0.8313
# Epoch 15/25
# 162/162 [==============================] - 656s 4s/step - loss: 0.5072 - accuracy: 0.8018 - val_loss: 0.4744 - val_accuracy: 0.8127
# Epoch 16/25
# 162/162 [==============================] - 657s 4s/step - loss: 0.4843 - accuracy: 0.8173 - val_loss: 0.4686 - val_accuracy: 0.8243
# Epoch 17/25
# 162/162 [==============================] - 653s 4s/step - loss: 0.4833 - accuracy: 0.8196 - val_loss: 0.4430 - val_accuracy: 0.8235
# Epoch 18/25
# 162/162 [==============================] - 656s 4s/step - loss: 0.4969 - accuracy: 0.8159 - val_loss: 0.4555 - val_accuracy: 0.8204
# Epoch 19/25
# 162/162 [==============================] - 654s 4s/step - loss: 0.4955 - accuracy: 0.8053 - val_loss: 0.4031 - val_accuracy: 0.8545
# Epoch 20/25
# 162/162 [==============================] - 656s 4s/step - loss: 0.4927 - accuracy: 0.8132 - val_loss: 0.4384 - val_accuracy: 0.8189
# Epoch 21/25
# 162/162 [==============================] - 656s 4s/step - loss: 0.4951 - accuracy: 0.8126 - val_loss: 0.4265 - val_accuracy: 0.8259
# Epoch 22/25
# 162/162 [==============================] - 656s 4s/step - loss: 0.4823 - accuracy: 0.8211 - val_loss: 0.4441 - val_accuracy: 0.8181
# Epoch 23/25
# 162/162 [==============================] - 674s 4s/step - loss: 0.4802 - accuracy: 0.8167 - val_loss: 0.4103 - val_accuracy: 0.8375
# Epoch 24/25
# 162/162 [==============================] - 652s 4s/step - loss: 0.4813 - accuracy: 0.8178 - val_loss: 0.4365 - val_accuracy: 0.8289
# Epoch 25/25
# 162/162 [==============================] - 657s 4s/step - loss: 0.4661 - accuracy: 0.8279 - val_loss: 0.4548 - val_accuracy: 0.8204

# %%
import matplotlib.pyplot as plt

fig1 = plt.gcf()

plt.plot(graph.history['accuracy'])
plt.plot(graph.history['val_accuracy'])

# plt.axis(ymin=0.4, ymax=1)
plt.grid()

plt.title('DenseNet121 Model Accuracy for COVID-19 Dataset')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','validation'])

plt.show()

# %%
max_acc = max(graph.history['val_accuracy'])

print('The highest accuracy achieved using DenseNet121 model is',max_acc*100)
# Out:
# The highest accuracy achieved using DenseNet121 model is 85.44891476631165
