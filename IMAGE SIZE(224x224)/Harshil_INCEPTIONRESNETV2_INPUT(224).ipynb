# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D, AveragePooling2D
from keras.layers.merge import concatenate

from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Flatten, Dense
from keras.layers import Activation
from keras.layers import BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping

from tensorflow import keras

from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import SGD
import cv2, numpy as np

# %%
train_datagen_with_aug = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,
                                   shear_range=0.2,
                                   zoom_range=[0.2,0.5],
                                   width_shift_range = 0.3,
                                   height_shift_range = 0.3,
                                   validation_split=0.2)

train_generator = train_datagen_with_aug.flow_from_directory(
    r'D:\My Work\Baranidharan Sir Research\cnn_xrays_images',
    target_size=(224, 224),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='training'
    ) # set as training data

validation_generator = train_datagen_with_aug.flow_from_directory(
    r'D:\My Work\Baranidharan Sir Research\cnn_xrays_images', # same directory as training data
    target_size=(224, 224),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='validation'
    ) # set as validation data

input_img = Input(shape=(224, 224, 3))
# Out:
# Found 5121 images belonging to 3 classes.
# Found 1278 images belonging to 3 classes.

# %%
from keras.applications import inception_resnet_v2

INCEPTION_RESNET_V2 = Sequential()

inceptionresnetv2_model = keras.applications.inception_resnet_v2.InceptionResNetV2(
    include_top=False, weights='imagenet',
    input_shape=(224,224,3), pooling=('max'), classes=3,
    classifier_activation='softmax'
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 14s 0us/step

# %%
for layer in inceptionresnetv2_model.layers:
    layer.trainable = False
    
INCEPTION_RESNET_V2.add(inceptionresnetv2_model)
INCEPTION_RESNET_V2.add(Flatten())
INCEPTION_RESNET_V2.add(Dense(512,activation='relu'))
INCEPTION_RESNET_V2.add(Dense(3, activation='softmax'))

INCEPTION_RESNET_V2.summary()

Adam = keras.optimizers.Adam(learning_rate=0.001)
INCEPTION_RESNET_V2.compile(optimizer=Adam, loss='categorical_crossentropy', metrics=['accuracy'])

graph = INCEPTION_RESNET_V2.fit(train_generator, epochs=25, validation_data = validation_generator)

graph
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v2 (Functio (None, 1536)              54336736
# _________________________________________________________________
# flatten (Flatten)            (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               786944
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 55,125,219
# Trainable params: 788,483
# Non-trainable params: 54,336,736
# _________________________________________________________________
# Epoch 1/25
# 161/161 [==============================] - 837s 5s/step - loss: 1.0927 - accuracy: 0.6341 - val_loss: 0.6639 - val_accuracy: 0.7089
# Epoch 2/25
# 161/161 [==============================] - 855s 5s/step - loss: 0.6632 - accuracy: 0.7268 - val_loss: 0.7209 - val_accuracy: 0.7058
# Epoch 3/25
# 161/161 [==============================] - 957s 6s/step - loss: 0.6399 - accuracy: 0.7319 - val_loss: 0.5545 - val_accuracy: 0.7731
# Epoch 4/25
# 161/161 [==============================] - 955s 6s/step - loss: 0.6279 - accuracy: 0.7440 - val_loss: 0.5446 - val_accuracy: 0.7793
# Epoch 5/25
# 161/161 [==============================] - 938s 6s/step - loss: 0.5918 - accuracy: 0.7598 - val_loss: 0.5607 - val_accuracy: 0.7567
# Epoch 6/25
# 161/161 [==============================] - 928s 6s/step - loss: 0.5993 - accuracy: 0.7620 - val_loss: 0.8000 - val_accuracy: 0.6354
# Epoch 7/25
# 161/161 [==============================] - 924s 6s/step - loss: 0.5844 - accuracy: 0.7721 - val_loss: 0.5211 - val_accuracy: 0.7973
# Epoch 8/25
# 161/161 [==============================] - 932s 6s/step - loss: 0.5390 - accuracy: 0.7905 - val_loss: 0.5587 - val_accuracy: 0.7512
# Epoch 9/25
# 161/161 [==============================] - 926s 6s/step - loss: 0.5653 - accuracy: 0.7797 - val_loss: 0.5619 - val_accuracy: 0.7629
# Epoch 10/25
# 161/161 [==============================] - 929s 6s/step - loss: 0.5940 - accuracy: 0.7616 - val_loss: 0.5262 - val_accuracy: 0.7903
# Epoch 11/25
# 161/161 [==============================] - 930s 6s/step - loss: 0.5513 - accuracy: 0.7791 - val_loss: 0.4820 - val_accuracy: 0.8177
# Epoch 12/25
# 161/161 [==============================] - 919s 6s/step - loss: 0.5570 - accuracy: 0.7758 - val_loss: 0.6178 - val_accuracy: 0.7066
# Epoch 13/25
# 161/161 [==============================] - 914s 6s/step - loss: 0.5914 - accuracy: 0.7602 - val_loss: 0.4833 - val_accuracy: 0.8067
# Epoch 14/25
# 161/161 [==============================] - 904s 6s/step - loss: 0.5473 - accuracy: 0.7862 - val_loss: 0.4687 - val_accuracy: 0.8099
# Epoch 15/25
# 161/161 [==============================] - 907s 6s/step - loss: 0.5669 - accuracy: 0.7786 - val_loss: 0.4960 - val_accuracy: 0.8216
# Epoch 16/25
# 161/161 [==============================] - 912s 6s/step - loss: 0.5188 - accuracy: 0.8012 - val_loss: 0.4815 - val_accuracy: 0.8091
# Epoch 17/25
# 161/161 [==============================] - 908s 6s/step - loss: 0.5400 - accuracy: 0.7866 - val_loss: 0.4379 - val_accuracy: 0.8396
# Epoch 18/25
# 161/161 [==============================] - 906s 6s/step - loss: 0.5169 - accuracy: 0.8008 - val_loss: 0.4488 - val_accuracy: 0.8200
# Epoch 19/25
# 161/161 [==============================] - 910s 6s/step - loss: 0.5596 - accuracy: 0.7803 - val_loss: 0.4804 - val_accuracy: 0.8114
# Epoch 20/25
# 161/161 [==============================] - 915s 6s/step - loss: 0.5342 - accuracy: 0.7924 - val_loss: 0.4497 - val_accuracy: 0.8114
# Epoch 21/25
# 161/161 [==============================] - 917s 6s/step - loss: 0.5095 - accuracy: 0.8037 - val_loss: 0.4610 - val_accuracy: 0.8192
# Epoch 22/25
# 161/161 [==============================] - 920s 6s/step - loss: 0.5078 - accuracy: 0.8065 - val_loss: 0.4771 - val_accuracy: 0.8318
# Epoch 23/25
# 161/161 [==============================] - 926s 6s/step - loss: 0.5164 - accuracy: 0.8016 - val_loss: 0.5279 - val_accuracy: 0.7825
# Epoch 24/25
# 161/161 [==============================] - 921s 6s/step - loss: 0.5095 - accuracy: 0.8059 - val_loss: 0.4390 - val_accuracy: 0.8279
# Epoch 25/25
# 161/161 [==============================] - 923s 6s/step - loss: 0.5061 - accuracy: 0.8114 - val_loss: 0.4521 - val_accuracy: 0.8341

# %%
import matplotlib.pyplot as plt

fig1 = plt.gcf()

plt.plot(graph.history['accuracy'])
plt.plot(graph.history['val_accuracy'])

# plt.axis(ymin=0.4, ymax=1)
plt.grid()

plt.title('VGG19 Accuracy for COVID-19 Dataset')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','validation'])

plt.show()
