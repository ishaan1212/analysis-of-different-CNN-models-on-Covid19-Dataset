# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D, AveragePooling2D
from keras.layers.merge import concatenate

from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Flatten, Dense
from keras.layers import Activation
from keras.layers import BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
from tensorflow import keras

# %%
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import SGD
import cv2, numpy as np

# %%
train_datagen_with_aug = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,
                                   shear_range=0.2,
                                   zoom_range=[0.2,0.5],
                                   width_shift_range = 0.3,
                                   height_shift_range = 0.3,
                                   validation_split=0.2)

train_generator = train_datagen_with_aug.flow_from_directory(
    r'D:\BARANIDHARAN SIR PROJECT\X-Ray Images Dataset for research project-20211204T084221Z-001',
    target_size=(512, 512),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='training'
    ) # set as training data

validation_generator = train_datagen_with_aug.flow_from_directory(
    r'D:\BARANIDHARAN SIR PROJECT\X-Ray Images Dataset for research project-20211204T084221Z-001', # same directory as training data
    target_size=(512, 512),
    batch_size=32,
    # color_mode='grayscale',
    class_mode='categorical',
    subset='validation'
    ) # set as validation data

input_img = Input(shape=(512, 512, 3))
# Out:
# Found 5171 images belonging to 3 classes.
# Found 1292 images belonging to 3 classes.

# %%
from keras.applications import VGG19

VGG_19_MODEL = Sequential()

vgg19 = keras.applications.vgg19.VGG19(
    include_top=False, weights='imagenet', input_tensor=None,
    input_shape=(512,512,3), pooling='max', classes=3,
    classifier_activation='softmax'
)

for layer in vgg19.layers:
    layer.trainable = False 
    
VGG_19_MODEL.add(vgg19)
VGG_19_MODEL.add(Flatten())
VGG_19_MODEL.add(Dense(512,activation='relu'))
VGG_19_MODEL.add(Dense(3, activation='softmax'))

VGG_19_MODEL.summary()

sgd = SGD(learning_rate=0.001, momentum=0.9)

VGG_19_MODEL.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

graph = VGG_19_MODEL.fit(train_generator, validation_data=validation_generator, epochs=25)

graph
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 512)               20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 20,288,579
# Trainable params: 264,195
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Epoch 1/25
# 162/162 [==============================] - 9028s 56s/step - loss: 1.0269 - accuracy: 0.4844 - val_loss: 0.9652 - val_accuracy: 0.5294
# Epoch 2/25
# 162/162 [==============================] - 20315s 125s/step - loss: 0.9644 - accuracy: 0.5368 - val_loss: 0.9243 - val_accuracy: 0.5565
# Epoch 3/25
# 162/162 [==============================] - 8585s 53s/step - loss: 0.9543 - accuracy: 0.5479 - val_loss: 0.9548 - val_accuracy: 0.5232
# Epoch 4/25
# 162/162 [==============================] - 8553s 53s/step - loss: 0.9260 - accuracy: 0.5695 - val_loss: 0.9040 - val_accuracy: 0.5580
# Epoch 5/25
# 162/162 [==============================] - 8519s 53s/step - loss: 0.9086 - accuracy: 0.5713 - val_loss: 0.8977 - val_accuracy: 0.5650
# Epoch 6/25
# 162/162 [==============================] - 8554s 53s/step - loss: 0.9027 - accuracy: 0.5726 - val_loss: 0.8942 - val_accuracy: 0.5828
# Epoch 7/25
# 162/162 [==============================] - 8594s 53s/step - loss: 0.8929 - accuracy: 0.5885 - val_loss: 0.8650 - val_accuracy: 0.6231
# Epoch 8/25
# 162/162 [==============================] - 8563s 53s/step - loss: 0.8839 - accuracy: 0.5838 - val_loss: 0.8422 - val_accuracy: 0.5913
# Epoch 9/25
# 162/162 [==============================] - 8531s 53s/step - loss: 0.8897 - accuracy: 0.5778 - val_loss: 0.8594 - val_accuracy: 0.5983
# Epoch 10/25
# 162/162 [==============================] - 8555s 53s/step - loss: 0.8717 - accuracy: 0.5945 - val_loss: 0.8530 - val_accuracy: 0.6494
# Epoch 11/25
# 162/162 [==============================] - 8526s 53s/step - loss: 0.8777 - accuracy: 0.5900 - val_loss: 0.8234 - val_accuracy: 0.6014
# Epoch 12/25
# 162/162 [==============================] - 8573s 53s/step - loss: 0.8585 - accuracy: 0.5978 - val_loss: 0.8368 - val_accuracy: 0.5805
# Epoch 13/25
# 162/162 [==============================] - 8568s 53s/step - loss: 0.8501 - accuracy: 0.6123 - val_loss: 0.8025 - val_accuracy: 0.6486
# Epoch 14/25
# 162/162 [==============================] - 8524s 53s/step - loss: 0.8515 - accuracy: 0.6072 - val_loss: 0.8245 - val_accuracy: 0.6455
# Epoch 15/25
# 162/162 [==============================] - 8526s 53s/step - loss: 0.8419 - accuracy: 0.6183 - val_loss: 0.8306 - val_accuracy: 0.6339
# Epoch 16/25
# 162/162 [==============================] - 8535s 53s/step - loss: 0.8455 - accuracy: 0.6130 - val_loss: 0.7806 - val_accuracy: 0.6246
# Epoch 17/25
# 162/162 [==============================] - 8965s 55s/step - loss: 0.8344 - accuracy: 0.6152 - val_loss: 0.8807 - val_accuracy: 0.5673
# Epoch 18/25
# 162/162 [==============================] - 8630s 53s/step - loss: 0.8275 - accuracy: 0.6152 - val_loss: 0.7858 - val_accuracy: 0.6262
# Epoch 19/25
# 162/162 [==============================] - 8864s 55s/step - loss: 0.8325 - accuracy: 0.6244 - val_loss: 0.7706 - val_accuracy: 0.6687
# Epoch 20/25
# 162/162 [==============================] - 8704s 54s/step - loss: 0.8154 - accuracy: 0.6295 - val_loss: 0.7508 - val_accuracy: 0.6672
# Epoch 21/25
# 162/162 [==============================] - 8741s 54s/step - loss: 0.8108 - accuracy: 0.6420 - val_loss: 0.7795 - val_accuracy: 0.6571
# Epoch 22/25
# 162/162 [==============================] - 8703s 54s/step - loss: 0.8237 - accuracy: 0.6331 - val_loss: 0.7646 - val_accuracy: 0.6331
# Epoch 23/25
# 162/162 [==============================] - 8661s 53s/step - loss: 0.8196 - accuracy: 0.6215 - val_loss: 0.7739 - val_accuracy: 0.6339
# Epoch 24/25
# 162/162 [==============================] - 8652s 53s/step - loss: 0.8098 - accuracy: 0.6370 - val_loss: 0.7628 - val_accuracy: 0.6416
# Epoch 25/25
# 162/162 [==============================] - 8637s 53s/step - loss: 0.8015 - accuracy: 0.6359 - val_loss: 0.7500 - val_accuracy: 0.6401

# %%
import matplotlib.pyplot as plt

fig1 = plt.gcf()

plt.plot(graph.history['accuracy'])
plt.plot(graph.history['val_accuracy'])

# plt.axis(ymin=0.4, ymax=1)
plt.grid()

plt.title('VGG19 Accuracy for COVID-19 Dataset')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','validation'])

plt.show()

# %%
max_acc = max(graph.history['val_accuracy'])

print('The highest accuracy achieved using DenseNet121 model is',max_acc*100)
# Out:
# The highest accuracy achieved using DenseNet121 model is 66.87306761741638
